# %% [markdown]
# # THE VACUUM WORLD
#
# In this notebook, we will be discussing **the structure of agents** through an example of the **vacuum agent**. The job of AI is to design an **agent program** that implements the agent function: the mapping from percepts to actions. We assume this program will run on some sort of computing device with physical sensors and actuators: we call this the **architecture**:
#
# <h3 align="center">agent = architecture + program</h3>

# %% [markdown]
# Before moving on, please review [<b>agents.ipynb</b>](https://github.com/aimacode/aima-python/blob/master/agents.ipynb)

# %% [markdown]
# ## CONTENTS
#
# * Agent
# * Random Agent Program
# * Table-Driven Agent Program
# * Simple Reflex Agent Program
# * Model-Based Reflex Agent Program
# * Goal-Based Agent Program
# * Utility-Based Agent Program
# * Learning Agent

# %% [markdown]
# ## AGENT PROGRAMS
#
# An agent program takes the current percept as input from the sensors and returns an action to the actuators. There is a difference between an agent program and an agent function: an agent program takes the current percept as input whereas an agent function takes the entire percept history.
#
# The agent program takes just the current percept as input because nothing more is available from the environment; if the agent's actions depend on the entire percept sequence, the agent will have to remember the percept.
#
# We'll discuss the following agent programs here with the help of the vacuum world example:
#
# * Random Agent Program
# * Table-Driven Agent Program
# * Simple Reflex Agent Program
# * Model-Based Reflex Agent Program
# * Goal-Based Agent Program
# * Utility-Based Agent Program

# %% [markdown]
# ## Random Agent Program
#
# A random agent program, as the name suggests, chooses an action at random, without taking into account the percepts.
# Here, we will demonstrate a random vacuum agent for a trivial vacuum environment, that is, the two-state environment.

# %% [markdown]
# Let's begin by importing all the functions from the agents module:

# %%
# !pip install ipythonblocks
# Out:
# Collecting ipythonblocks
#   Using cached ipythonblocks-1.9.1-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: ipython>=4.0 in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipythonblocks) (8.12.3)
# Collecting notebook>=4.0 (from ipythonblocks)
#   Using cached notebook-7.2.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=1.0 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from ipythonblocks) (2.31.0)
# Requirement already satisfied: backcall in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (0.2.0)
# Requirement already satisfied: decorator in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (0.1.7)
# Requirement already satisfied: pickleshare in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (0.6.3)
# Requirement already satisfied: traitlets>=5 in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (5.14.3)
# Requirement already satisfied: typing-extensions in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from ipython>=4.0->ipythonblocks) (4.12.2)
# Requirement already satisfied: colorama in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipython>=4.0->ipythonblocks) (0.4.6)
# Collecting jupyter-server<3,>=2.4.0 (from notebook>=4.0->ipythonblocks)
#   Using cached jupyter_server-2.14.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from notebook>=4.0->ipythonblocks)
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.3,>=4.2.0 (from notebook>=4.0->ipythonblocks)
#   Using cached jupyterlab-4.2.5-py3-none-any.whl.metadata (16 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook>=4.0->ipythonblocks)
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\39346\appdata\roaming\python\python38\site-packages (from notebook>=4.0->ipythonblocks) (6.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from requests>=1.0->ipythonblocks) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from requests>=1.0->ipythonblocks) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from requests>=1.0->ipythonblocks) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from requests>=1.0->ipythonblocks) (2024.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\39346\appdata\roaming\python\python38\site-packages (from jedi>=0.16->ipython>=4.0->ipythonblocks) (0.8.4)
# Collecting anyio>=3.1.0 (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Downloading anyio-4.5.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2>=3.0.3 (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\39346\appdata\roaming\python\python38\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks) (8.6.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\39346\appdata\roaming\python\python38\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks) (5.7.2)
# Collecting jupyter-events>=0.9.0 (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached jupyter_events-0.10.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbconvert>=6.4.4 (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached nbconvert-7.16.4-py3-none-any.whl.metadata (8.5 kB)
# Collecting nbformat>=5.3.0 (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: packaging>=22.0 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks) (24.0)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached prometheus_client-0.21.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pywinpty>=2.0.1 (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Downloading pywinpty-2.0.13-cp38-none-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: pyzmq>=24 in c:\users\39346\appdata\roaming\python\python38\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks) (26.0.3)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks)
#   Using cached async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx>=0.25.0 (from jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks)
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks) (7.1.0)
# Requirement already satisfied: importlib-resources>=1.4 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks) (6.4.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\39346\appdata\roaming\python\python38\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks) (6.29.4)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks)
#   Using cached jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks) (49.2.1)
# Collecting tomli>=1.2.2 (from jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks)
#   Downloading tomli-2.0.2-py3-none-any.whl.metadata (10.0 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->notebook>=4.0->ipythonblocks)
#   Using cached babel-2.16.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->notebook>=4.0->ipythonblocks)
#   Using cached json5-0.9.25-py3-none-any.whl.metadata (30 kB)
# Collecting jsonschema>=4.18.0 (from jupyterlab-server<3,>=2.27.1->notebook>=4.0->ipythonblocks)
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: wcwidth in c:\users\39346\appdata\roaming\python\python38\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=4.0->ipythonblocks) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\39346\appdata\roaming\python\python38\site-packages (from stack-data->ipython>=4.0->ipythonblocks) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\39346\appdata\roaming\python\python38\site-packages (from stack-data->ipython>=4.0->ipythonblocks) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\39346\appdata\roaming\python\python38\site-packages (from stack-data->ipython>=4.0->ipythonblocks) (0.2.2)
# Collecting sniffio>=1.1 (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting exceptiongroup>=1.0.2 (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=4.0->ipythonblocks) (1.15.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook>=4.0->ipythonblocks) (2024.1)
# Collecting httpcore==1.* (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks)
#   Using cached httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from importlib-metadata>=4.8.3->jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks) (3.18.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks) (1.8.1)
# Requirement already satisfied: nest-asyncio in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks) (1.6.0)
# Requirement already satisfied: psutil in c:\users\39346\appdata\roaming\python\python38\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.0->ipythonblocks) (5.9.8)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks) (2.1.5)
# Collecting attrs>=22.2.0 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.0->ipythonblocks)
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.0->ipythonblocks)
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pkgutil-resolve-name>=1.3.10 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.0->ipythonblocks)
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl.metadata (624 bytes)
# Collecting referencing>=0.28.4 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.0->ipythonblocks)
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.0->ipythonblocks)
#   Downloading rpds_py-0.20.0-cp38-none-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\39346\appdata\roaming\python\python38\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks) (4.2.1)
# Requirement already satisfied: pywin32>=300 in c:\users\39346\appdata\roaming\python\python38\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks) (306)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Collecting pyyaml>=5.3 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Downloading PyYAML-6.0.2-cp38-cp38-win_amd64.whl.metadata (2.1 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting beautifulsoup4 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached nbclient-0.10.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting tinycss2 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached tinycss2-1.3.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached fastjsonschema-2.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting webencodings (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached webcolors-24.8.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Downloading cffi-1.17.1-cp38-cp38-win_amd64.whl.metadata (1.6 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting types-python-dateutil>=2.8.10 (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.0->ipythonblocks)
#   Using cached types_python_dateutil-2.9.0.20241003-py3-none-any.whl.metadata (1.9 kB)
# Using cached ipythonblocks-1.9.1-py2.py3-none-any.whl (14 kB)
# Using cached notebook-7.2.2-py3-none-any.whl (5.0 MB)
# Using cached jupyter_server-2.14.2-py3-none-any.whl (383 kB)
# Using cached jupyterlab-4.2.5-py3-none-any.whl (11.6 MB)
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading anyio-4.5.0-py3-none-any.whl (89 kB)
#    ---------------------------------------- 0.0/89.2 kB ? eta -:--:--
#    ---------------------------------------- 89.2/89.2 kB 4.9 MB/s eta 0:00:00
# Using cached argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Using cached async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Using cached babel-2.16.0-py3-none-any.whl (9.6 MB)
# Using cached httpx-0.27.2-py3-none-any.whl (76 kB)
# Using cached httpcore-1.0.6-py3-none-any.whl (78 kB)
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.3 kB ? eta -:--:--
#    ---------------------------------------- 133.3/133.3 kB 7.7 MB/s eta 0:00:00
# Using cached json5-0.9.25-py3-none-any.whl (30 kB)
# Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Using cached jupyter_events-0.10.0-py3-none-any.whl (18 kB)
# Using cached jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Using cached nbconvert-7.16.4-py3-none-any.whl (257 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached prometheus_client-0.21.0-py3-none-any.whl (54 kB)
# Downloading pywinpty-2.0.13-cp38-none-win_amd64.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------  1.4/1.4 MB 29.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 22.4 MB/s eta 0:00:00
# Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading tomli-2.0.2-py3-none-any.whl (13 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached attrs-24.2.0-py3-none-any.whl (63 kB)
# Using cached bleach-6.1.0-py3-none-any.whl (162 kB)
# Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Using cached fastjsonschema-2.20.0-py3-none-any.whl (23 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Using cached mistune-3.0.2-py3-none-any.whl (47 kB)
# Using cached nbclient-0.10.0-py3-none-any.whl (25 kB)
# Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Using cached python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Downloading PyYAML-6.0.2-cp38-cp38-win_amd64.whl (162 kB)
#    ---------------------------------------- 0.0/162.7 kB ? eta -:--:--
#    ---------------------------------------- 162.7/162.7 kB 9.5 MB/s eta 0:00:00
# Using cached referencing-0.35.1-py3-none-any.whl (26 kB)
# Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rpds_py-0.20.0-cp38-none-win_amd64.whl (213 kB)
#    ---------------------------------------- 0.0/213.0 kB ? eta -:--:--
#    --------------------------------------- 213.0/213.0 kB 12.7 MB/s eta 0:00:00
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Using cached tinycss2-1.3.0-py3-none-any.whl (22 kB)
# Downloading cffi-1.17.1-cp38-cp38-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.2 kB ? eta -:--:--
#    --------------------------------------- 181.2/181.2 kB 11.4 MB/s eta 0:00:00
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Using cached webcolors-24.8.0-py3-none-any.whl (15 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Using cached arrow-1.3.0-py3-none-any.whl (66 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Using cached types_python_dateutil-2.9.0.20241003-py3-none-any.whl (9.7 kB)
# Installing collected packages: webencodings, fastjsonschema, websocket-client, webcolors, uri-template, types-python-dateutil, tomli, tinycss2, soupsieve, sniffio, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, pyyaml, pywinpty, python-json-logger, pycparser, prometheus-client, pkgutil-resolve-name, pandocfilters, overrides, mistune, jupyterlab-pygments, jsonpointer, json5, jinja2, h11, fqdn, exceptiongroup, defusedxml, bleach, babel, attrs, async-lru, terminado, referencing, httpcore, cffi, beautifulsoup4, arrow, anyio, jupyter-server-terminals, jsonschema-specifications, isoduration, httpx, argon2-cffi-bindings, jsonschema, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, ipythonblocks
# Successfully installed anyio-4.5.0 argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 arrow-1.3.0 async-lru-2.0.4 attrs-24.2.0 babel-2.16.0 beautifulsoup4-4.12.3 bleach-6.1.0 cffi-1.17.1 defusedxml-0.7.1 exceptiongroup-1.2.2 fastjsonschema-2.20.0 fqdn-1.5.1 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 ipythonblocks-1.9.1 isoduration-20.11.0 jinja2-3.1.4 json5-0.9.25 jsonpointer-3.0.0 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 jupyter-events-0.10.0 jupyter-lsp-2.2.5 jupyter-server-2.14.2 jupyter-server-terminals-0.5.3 jupyterlab-4.2.5 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 mistune-3.0.2 nbclient-0.10.0 nbconvert-7.16.4 nbformat-5.10.4 notebook-7.2.2 notebook-shim-0.2.4 overrides-7.7.0 pandocfilters-1.5.1 pkgutil-resolve-name-1.3.10 prometheus-client-0.21.0 pycparser-2.22 python-json-logger-2.0.7 pywinpty-2.0.13 pyyaml-6.0.2 referencing-0.35.1 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rpds-py-0.20.0 send2trash-1.8.3 sniffio-1.3.1 soupsieve-2.6 terminado-0.18.1 tinycss2-1.3.0 tomli-2.0.2 types-python-dateutil-2.9.0.20241003 uri-template-1.3.0 webcolors-24.8.0 webencodings-0.5.1 websocket-client-1.8.0
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\39346\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\39346\appdata\local\programs\python\python38\lib\site-packages)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: c:\users\39346\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip

# %%
# !pip install qpsolvers
# Out:
# Collecting qpsolvers
#   Using cached qpsolvers-4.4.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\39346\appdata\local\programs\python\python38\lib\site-packages (from qpsolvers) (1.24.4)
# Collecting scipy>=1.2.0 (from qpsolvers)
#   Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata (58 kB)
#      ---------------------------------------- 0.0/59.0 kB ? eta -:--:--
#      ---------------------------------------- 59.0/59.0 kB 3.0 MB/s eta 0:00:00
# Using cached qpsolvers-4.4.0-py3-none-any.whl (82 kB)
# Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
#    ---------------------------------------- 0.0/42.2 MB ? eta -:--:--
#    - -------------------------------------- 1.1/42.2 MB 22.7 MB/s eta 0:00:02
#    - -------------------------------------- 2.1/42.2 MB 26.7 MB/s eta 0:00:02
#    -- ------------------------------------- 2.1/42.2 MB 13.7 MB/s eta 0:00:03
#    -- ------------------------------------- 3.1/42.2 MB 16.7 MB/s eta 0:00:03
#    -- ------------------------------------- 3.2/42.2 MB 11.8 MB/s eta 0:00:04
#    --- ------------------------------------ 4.2/42.2 MB 14.1 MB/s eta 0:00:03
#    --- ------------------------------------ 4.2/42.2 MB 14.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 5.2/42.2 MB 12.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 5.2/42.2 MB 12.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 6.3/42.2 MB 12.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 6.3/42.2 MB 12.2 MB/s eta 0:00:03
#    ------- -------------------------------- 7.7/42.2 MB 12.3 MB/s eta 0:00:03
#    ------- -------------------------------- 8.4/42.2 MB 13.1 MB/s eta 0:00:03
#    -------- ------------------------------- 8.7/42.2 MB 12.1 MB/s eta 0:00:03
#    --------- ------------------------------ 10.5/42.2 MB 13.9 MB/s eta 0:00:03
#    --------- ------------------------------ 10.5/42.2 MB 13.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 11.3/42.2 MB 12.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 12.6/42.2 MB 14.2 MB/s eta 0:00:03
#    ------------ --------------------------- 12.8/42.2 MB 13.1 MB/s eta 0:00:03
#    ------------- -------------------------- 14.4/42.2 MB 16.4 MB/s eta 0:00:02
#    -------------- ------------------------- 15.7/42.2 MB 19.3 MB/s eta 0:00:02
#    --------------- ------------------------ 16.3/42.2 MB 17.7 MB/s eta 0:00:02
#    --------------- ------------------------ 16.8/42.2 MB 19.8 MB/s eta 0:00:02
#    --------------- ------------------------ 16.8/42.2 MB 19.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 17.8/42.2 MB 17.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 17.8/42.2 MB 17.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 17.8/42.2 MB 17.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 18.6/42.2 MB 14.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 18.9/42.2 MB 14.6 MB/s eta 0:00:02
#    ------------------- -------------------- 20.1/42.2 MB 12.8 MB/s eta 0:00:02
#    --------------------- ------------------ 22.3/42.2 MB 13.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 24.1/42.2 MB 14.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 24.6/42.2 MB 13.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 25.2/42.2 MB 13.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 25.2/42.2 MB 12.6 MB/s eta 0:00:02
#    ------------------------ --------------- 26.2/42.2 MB 12.6 MB/s eta 0:00:02
#    ------------------------- -------------- 26.8/42.2 MB 12.1 MB/s eta 0:00:02
#    ------------------------- -------------- 27.3/42.2 MB 13.4 MB/s eta 0:00:02
#    -------------------------- ------------- 27.5/42.2 MB 12.1 MB/s eta 0:00:02
#    --------------------------- ------------ 28.6/42.2 MB 14.9 MB/s eta 0:00:01
#    --------------------------- ------------ 29.4/42.2 MB 16.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 30.1/42.2 MB 16.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 30.4/42.2 MB 16.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 30.4/42.2 MB 16.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 31.5/42.2 MB 14.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 31.5/42.2 MB 14.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 31.6/42.2 MB 12.6 MB/s eta 0:00:01
#    ------------------------------ --------- 32.5/42.2 MB 12.1 MB/s eta 0:00:01
#    ------------------------------- -------- 33.1/42.2 MB 11.1 MB/s eta 0:00:01
#    ------------------------------- -------- 33.5/42.2 MB 11.1 MB/s eta 0:00:01
#    -------------------------------- ------- 34.3/42.2 MB 10.4 MB/s eta 0:00:01
#    -------------------------------- ------- 34.6/42.2 MB 10.6 MB/s eta 0:00:01
#    -------------------------------- ------- 34.6/42.2 MB 10.6 MB/s eta 0:00:01
#    -------------------------------- ------- 34.6/42.2 MB 10.6 MB/s eta 0:00:01
#    -------------------------------- ------- 34.6/42.2 MB 10.6 MB/s eta 0:00:01
#    -------------------------------- ------- 34.6/42.2 MB 10.6 MB/s eta 0:00:01
#    -------------------------------- ------- 34.6/42.2 MB 10.6 MB/s eta 0:00:01
#    -------------------------------- ------- 34.6/42.2 MB 10.6 MB/s eta 0:00:01
#    -------------------------------- ------- 34.6/42.2 MB 10.6 MB/s eta 0:00:01
#    --------------------------------- ------ 34.9/42.2 MB 6.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 36.7/42.2 MB 7.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 37.0/42.2 MB 7.4 MB/s eta 0:00:01
#    ------------------------------------ --- 38.5/42.2 MB 7.9 MB/s eta 0:00:01
#    ------------------------------------ --- 38.8/42.2 MB 7.8 MB/s eta 0:00:01
#    ------------------------------------- -- 39.9/42.2 MB 7.9 MB/s eta 0:00:01
#    -------------------------------------- - 40.9/42.2 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  41.9/42.2 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 42.2/42.2 MB 8.1 MB/s eta 0:00:00
# Installing collected packages: scipy, qpsolvers
# Successfully installed qpsolvers-4.4.0 scipy-1.10.1
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\39346\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\39346\appdata\local\programs\python\python38\lib\site-packages)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: c:\users\39346\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip

# %%
from agents import *
from notebook import psource
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 2
#       1 from agents import *
# ----> 2 from notebook import psource
#
# ImportError: cannot import name 'psource' from 'notebook' (c:\Users\39346\AppData\Local\Programs\Python\Python312\Lib\site-packages\notebook\__init__.py)

# %% [markdown]
# Let us first see how we define the TrivialVacuumEnvironment. Run the next cell to see how abstract class TrivialVacuumEnvironment is defined in agents module:

# %%
psource(TrivialVacuumEnvironment)
# Out:
# Object `(TrivialVacuumEnvironment)` not found.

# %%
# TWO LOCATIONS; BOTH CLEANED
# These are the two locations for the two-state environment
loc_A, loc_B = (0, 0), (1, 0)

# Initialize the two-state environment
trivial_vacuum_env = TrivialVacuumEnvironment()

# Check the initial state of the environment
print("State of the Environment: {}.".format(trivial_vacuum_env.status))
# Out:
# State of the Environment: {(0, 0): 'Clean', (1, 0): 'Clean'}.

# %% [markdown]
# Let's create our agent now. This agent will choose any of the actions from 'Right', 'Left', 'Suck' and 'NoOp' (No Operation) randomly.

# %%
psource(RandomAgentProgram)
# Out:
# Object `(RandomAgentProgram)` not found.

# %%
# Create the random agent
# NOTICE THE RANDOM.CHOICE FUNCTION IN THE DEFINITION OF THE RANDOM AGENT PROGRAM
random_agent = Agent(program=RandomAgentProgram(['Right', 'Left', 'Suck', 'NoOp']))

# %% [markdown]
# We will now add our agent to the environment.

# %%
# Add agent to the environment BY USING ADD_THING METHOD
trivial_vacuum_env.add_thing(random_agent)

print("RandomVacuumAgent is located at {}.".format(random_agent.location))
# Out:
# RandomVacuumAgent is located at (0, 0).

# %% [markdown]
# Let's run our environment now.

# %%
# Running the environment
trivial_vacuum_env.step()

# Check the current state of the environment
print("State of the Environment: {}.".format(trivial_vacuum_env.status))

print("RandomVacuumAgent is located at {}.".format(random_agent.location))
# Out:
# State of the Environment: {(0, 0): 'Clean', (1, 0): 'Clean'}.
# RandomVacuumAgent is located at (1, 0).

# %% [markdown]
# ## TABLE-DRIVEN AGENT PROGRAM
#
# A table-driven agent program keeps track of the percept sequence and then uses it to index into a table of actions to decide what to do. The table represents explicitly the agent function that the agent program embodies.
# In the two-state vacuum world, the table would consist of all the possible states of the agent.

# %%
table = {((loc_A, 'Clean'),): 'Right',
             ((loc_A, 'Dirty'),): 'Suck',
             ((loc_B, 'Clean'),): 'Left',
             ((loc_B, 'Dirty'),): 'Suck',
             ((loc_A, 'Dirty'), (loc_A, 'Clean')): 'Right',
             ((loc_A, 'Clean'), (loc_B, 'Dirty')): 'Suck',
             ((loc_B, 'Clean'), (loc_A, 'Dirty')): 'Suck',
             ((loc_B, 'Dirty'), (loc_B, 'Clean')): 'Left',
             ((loc_A, 'Dirty'), (loc_A, 'Clean'), (loc_B, 'Dirty')): 'Suck',
             ((loc_B, 'Dirty'), (loc_B, 'Clean'), (loc_A, 'Dirty')): 'Suck'
        }

# %% [markdown]
# We will now create a table-driven agent program for our two-state environment.

# %%
psource(TableDrivenAgentProgram)
# Out:
# Object `(TableDrivenAgentProgram)` not found.

# %%
# Create a table-driven agent
# THE ACTION IS TAKEN DIRECTLY FROM THE TABLE PASSED AS INPUT
table_driven_agent = Agent(program=TableDrivenAgentProgram(table=table))

# %% [markdown]
# Since we are using the same environment, let's remove the previously added random agent from the environment to avoid confusion.

# %%
trivial_vacuum_env.delete_thing(random_agent)

# %%
# Add the table-driven agent to the environment
trivial_vacuum_env.add_thing(table_driven_agent)

print("TableDrivenVacuumAgent is located at {}.".format(table_driven_agent.location))
# Out:
# TableDrivenVacuumAgent is located at (1, 0).

# %%
# Run the environment
trivial_vacuum_env.step()

# Check the current state of the environment
print("State of the Environment: {}.".format(trivial_vacuum_env.status))

print("TableDrivenVacuumAgent is located at {}.".format(table_driven_agent.location))
# Out:
# State of the Environment: {(0, 0): 'Clean', (1, 0): 'Clean'}.
# TableDrivenVacuumAgent is located at (0, 0).

# %% [markdown]
# ## SIMPLE REFLEX AGENT PROGRAM
#
# A simple reflex agent program selects actions on the basis of the *current* percept, ignoring the rest of the percept history. These agents work on a **condition-action rule** (also called **situation-action rule**, **production** or **if-then rule**), which tells the agent the action to trigger when a particular situation is encountered.
#
# The schematic diagram shown in **Figure 2.9** of the book will make this more clear:
#
# "![simple reflex agent](images/simple_reflex_agent.jpg)"

# %% [markdown]
# Let us now create a simple reflex agent for the environment.

# %%
# Delete the previously added table-driven agent
trivial_vacuum_env.delete_thing(table_driven_agent)

# %% [markdown]
# To create our agent, we need two functions: INTERPRET-INPUT function, which generates an abstracted description of the current state from the percerpt and the RULE-MATCH function, which returns the first rule in the set of rules that matches the given state description.

# %%
psource(SimpleReflexAgentProgram)
# NOTICE THAT JUST BY LOOKING AT THE CURRENT STATE, THE ACTION IS CHOSEN VIA SOME RULE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 psource(SimpleReflexAgentProgram)
#       2 # NOTICE THAT JUST BY LOOKING AT THE CURRENT STATE, THE ACTION IS CHOSEN VIA SOME RULE
#
# NameError: name 'psource' is not defined

# %%
loc_A = (0, 0)
loc_B = (1, 0)

"""We change the simpleReflexAgentProgram so that it doesn't make use of the Rule class"""
def SimpleReflexAgentProgram():
    """This agent takes action based solely on the percept. [Figure 2.10]"""

    def program(percept):
        loc, status = percept
        return ('Suck' if status == 'Dirty'
                else'Right' if loc == loc_A
                            else'Left')
    return program


# Create a simple reflex agent the two-state environment
program = SimpleReflexAgentProgram()
simple_reflex_agent = Agent(program)

# %% [markdown]
# Now add the agent to the environment:

# %%
trivial_vacuum_env.add_thing(simple_reflex_agent)

print("SimpleReflexVacuumAgent is located at {}.".format(simple_reflex_agent.location))
# Out:
# SimpleReflexVacuumAgent is located at (1, 0).

# %%
# Run the environment
trivial_vacuum_env.step()

# Check the current state of the environment
print("State of the Environment: {}.".format(trivial_vacuum_env.status))

print("SimpleReflexVacuumAgent is located at {}.".format(simple_reflex_agent.location))
# Out:
# State of the Environment: {(0, 0): 'Clean', (1, 0): 'Clean'}.
# SimpleReflexVacuumAgent is located at (0, 0).

# %% [markdown]
# ## MODEL-BASED REFLEX AGENT PROGRAM
#
# A model-based reflex agent maintains some sort of **internal state** that depends on the percept history and thereby reflects at least some of the unobserved aspects of the current state. In addition to this, it also requires a **model** of the world, that is, knowledge about "how the world works".
#
# The schematic diagram shown in **Figure 2.11** of the book will make this more clear:
# <img src="files/images/model_based_reflex_agent.jpg">

# %% [markdown]
# We will now create a model-based reflex agent for the environment:

# %%
# Delete the previously added simple reflex agent
trivial_vacuum_env.delete_thing(simple_reflex_agent)
# Out:
# list.remove(x): x not in list
#   in Environment delete_thing
#   Thing to be removed: <Agent> at (0, 0)
#   from list: [(<Agent>, (1, 0))]

# %% [markdown]
# We need another function UPDATE-STATE which will be responsible for creating a new state description.

# %%
psource(ModelBasedVacuumAgent)
# Out:
# Object `(ModelBasedVacuumAgent)` not found.

# %%
def update_state(state, action, percept, model):
    # one can appropriately modify this function
    pass

# Create a model-based reflex agent
model_based_reflex_agent = ModelBasedVacuumAgent()

# Add the agent to the environment
trivial_vacuum_env.add_thing(model_based_reflex_agent)

print("ModelBasedVacuumAgent is located at {}.".format(model_based_reflex_agent.location))
# Out:
# ModelBasedVacuumAgent is located at (0, 0).

# %%
# Run the environment
trivial_vacuum_env.step()

# Check the current state of the environment
print("State of the Environment: {}.".format(trivial_vacuum_env.status))

print("ModelBasedVacuumAgent is located at {}.".format(model_based_reflex_agent.location))
# Out:
# State of the Environment: {(0, 0): 'Clean', (1, 0): 'Clean'}.
# ModelBasedVacuumAgent is located at (1, 0).

# %% [markdown]
# ## GOAL-BASED AGENT PROGRAM
#
# A goal-based agent needs some sort of **goal** information that describes situations that are desirable, apart from the current state description.
#
# **Figure 2.13** of the book shows a model-based, goal-based agent:
# <img src="files/images/model_goal_based_agent.jpg">
#
# **Search** (Chapters 3 to 5) and **Planning** (Chapters 10 to 11) are the subfields of AI devoted to finding action sequences that achieve the agent's goals.
#
# ## UTILITY-BASED AGENT PROGRAM
#
# A utility-based agent maximizes its **utility** using the agent's **utility function**, which is essentially an internalization of the agent's performance measure.
#
# **Figure 2.14** of the book shows a model-based, utility-based agent:
# <img src="files/images/model_utility_based_agent.jpg">

# %% [markdown]
# ## LEARNING AGENT
#
# Learning allows the agent to operate in initially unknown environments and to become more competent than its initial knowledge alone might allow. Here, we will breifly introduce the main ideas of learning agents.
#
# A learning agent can be divided into four conceptual components. The **learning element** is responsible for making improvements. It uses the feedback from the **critic** on how the agent is doing and determines how the performance element should be modified to do better in the future. The **performance element** is responsible for selecting external actions for the agent: it takes in percepts and decides on actions. The critic tells the learning element how well the agent is doing with respect to a fixed performance standard. It is necesaary because the percepts themselves provide no indication of the agent's success. The last component of the learning agent is the **problem generator**. It is responsible for suggesting actions that will lead to new and informative experiences.
#
# **Figure 2.15** of the book sums up the components and their working:
# <img src="files/images/general_learning_agent.jpg">
